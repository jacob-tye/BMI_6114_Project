# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Machine Learning Analysis

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
import joblib

from utils.helper_functions import split_data

# %%
cancer_df = pd.read_csv("../data/cleaned_feature_and_target_data_large.csv", index_col=0)
cna_columns = [col for col in cancer_df.columns if col.startswith("CNA")]
numeric_cols = ["SMOKING_PACK_YEARS"] + cna_columns
cancer_df[numeric_cols] = cancer_df[numeric_cols].astype(np.float32)
scaler = joblib.load(open("results/scaler.pkl", "rb"))

# %%
train_df, val_df, test_df = split_data(cancer_df)

# %%
train_df.loc[:, numeric_cols] = scaler.transform(train_df[numeric_cols])
val_df.loc[:, numeric_cols] = scaler.transform(val_df[numeric_cols])
test_df.loc[:, numeric_cols] = scaler.transform(test_df[numeric_cols])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import TransformedTargetRegressor

def create_pipeline(model_args = {}):
    """
    Create a pipeline with the given model.
    """
    from sklearn.pipeline import Pipeline
    from sklearn.preprocessing import StandardScaler
    from sklearn.compose import TransformedTargetRegressor

    preprocessor = ColumnTransformer(
            transformers=[
                ('scaler', StandardScaler(), numeric_cols)
            ],
            remainder='passthrough',
            force_int_remainder_cols=False
        )

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', TransformedTargetRegressor(
            regressor=RandomForestRegressor(**model_args),
            transformer=FunctionTransformer(np.log1p, inverse_func=np.expm1)
        ))
    ])
    return pipeline

# %%
from utils.helper_functions import plot_regression_results_sklearn, get_features_and_target


model_args = {
    "n_estimators": 100,
    "max_depth": 10,
    "min_samples_split": 2,
    "min_samples_leaf": 1,
    "max_features": "sqrt",
    "random_state": 42
}
model = create_pipeline(model_args)
train_features, train_target = get_features_and_target(train_df)
model.fit(train_features, train_target)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('scaler', StandardScaler(),
#                                                   ['SMOKING_PACK_YEARS',
#                                                    'CNA_CHD5', 'CNA_PTCHD2',
#                                                    'CNA_VPS13D', 'CNA_UBR4',
#                                                    'CNA_HSPG2', 'CNA_ARID1A',
#                                                    'CNA_CSMD2', 'CNA_MACF1',
#                                                    'CNA_LRRC7', 'CNA_C1orf173',
#                                                    'CNA_LPHN2', 'CNA_COL24A1',
#                                                    'CNA_LPPR4', 'CNA_COL11A1',
#                                                    'CNA_S...
#                                                    'CNA_TCHH', 'CNA_HRNR',
#                                                    'CNA_FLG', 'CNA_FLG2',
#                                                    'CNA_FCRL5', 'CNA_SPTA1',
#                                                    'CNA_DUSP27', 'CNA_F5',
#                                                    'CNA_TNN', 'CNA_TNR',
#                                                    'CNA_PAPPA2', 'CNA_ASTN1',
#                                                    'CNA_CACNA1E', ...])])),
#                 ('regressor',
#                  TransformedTargetRegressor(regressor=RandomForestRegressor(max_depth=10,
#                                                                             max_features='sqrt',
#                                                                             random_state=42),
#                                             transformer=FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                             inverse_func=<ufunc 'expm1'>)))])

# %%
plot_regression_results_sklearn(model, test_df)

# %%
import optuna
from sklearn.metrics import mean_squared_error

def objective(trial : optuna.Trial):
    n_estimators = trial.suggest_int("n_estimators", 10, 1000)
    max_depth = trial.suggest_int("max_depth", 1, 400)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 40)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 40)
    model = create_pipeline({
        "n_estimators": n_estimators,
        "max_depth": max_depth,
        "min_samples_split": min_samples_split,
        "min_samples_leaf": min_samples_leaf,
        "random_state": 42
        })
    train_features, train_target = get_features_and_target(train_df)
    val_features, val_target = get_features_and_target(val_df)


    model.fit(train_features, train_target)
    mse = mean_squared_error(val_target, model.predict(val_features))
    return  mse

# %%
# --- Run Optuna ---
study = optuna.create_study(direction="minimize", study_name="rf_study")
study.optimize(objective, n_trials=50, n_jobs=-1, show_progress_bar=True)

# --- Print Best Result ---
print("Best trial:")
print(f"  Value (val_mse): {study.best_trial.value}")
print("  Params:")
for key, val in study.best_trial.params.items():
    print(f"    {key}: {val}")
# Out:
# [I 2025-04-18 10:57:25,696] A new study created in memory with name: rf_study
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-04-18 10:57:37,617] Trial 10 finished with value: 788.1571195956514 and parameters: {'n_estimators': 67, 'max_depth': 106, 'min_samples_split': 14, 'min_samples_leaf': 36}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:40,247] Trial 12 finished with value: 791.6969706734398 and parameters: {'n_estimators': 84, 'max_depth': 11, 'min_samples_split': 36, 'min_samples_leaf': 32}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:43,734] Trial 16 finished with value: 794.1394383833373 and parameters: {'n_estimators': 17, 'max_depth': 154, 'min_samples_split': 14, 'min_samples_leaf': 25}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:48,635] Trial 1 finished with value: 790.9031010413391 and parameters: {'n_estimators': 159, 'max_depth': 48, 'min_samples_split': 17, 'min_samples_leaf': 36}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:49,793] Trial 2 finished with value: 791.2260553294584 and parameters: {'n_estimators': 163, 'max_depth': 40, 'min_samples_split': 9, 'min_samples_leaf': 38}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:52,479] Trial 8 finished with value: 790.4663151863505 and parameters: {'n_estimators': 168, 'max_depth': 124, 'min_samples_split': 8, 'min_samples_leaf': 20}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:57:58,048] Trial 14 finished with value: 789.6115554238404 and parameters: {'n_estimators': 167, 'max_depth': 161, 'min_samples_split': 33, 'min_samples_leaf': 4}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:12,988] Trial 19 finished with value: 791.5410518834985 and parameters: {'n_estimators': 187, 'max_depth': 26, 'min_samples_split': 37, 'min_samples_leaf': 38}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:13,654] Trial 13 finished with value: 790.7736963505877 and parameters: {'n_estimators': 285, 'max_depth': 44, 'min_samples_split': 18, 'min_samples_leaf': 12}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:16,241] Trial 6 finished with value: 790.1104894494813 and parameters: {'n_estimators': 348, 'max_depth': 130, 'min_samples_split': 11, 'min_samples_leaf': 23}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:19,334] Trial 4 finished with value: 793.2998654995575 and parameters: {'n_estimators': 410, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 37}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:22,435] Trial 11 finished with value: 792.98190959333 and parameters: {'n_estimators': 433, 'max_depth': 33, 'min_samples_split': 21, 'min_samples_leaf': 34}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:30,030] Trial 17 finished with value: 792.9706044749163 and parameters: {'n_estimators': 399, 'max_depth': 230, 'min_samples_split': 19, 'min_samples_leaf': 32}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:42,402] Trial 0 finished with value: 792.4882210254137 and parameters: {'n_estimators': 660, 'max_depth': 282, 'min_samples_split': 10, 'min_samples_leaf': 40}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:47,784] Trial 3 finished with value: 790.1063701483919 and parameters: {'n_estimators': 518, 'max_depth': 289, 'min_samples_split': 16, 'min_samples_leaf': 12}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:50,412] Trial 24 finished with value: 792.1884174111473 and parameters: {'n_estimators': 270, 'max_depth': 136, 'min_samples_split': 22, 'min_samples_leaf': 29}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:56,111] Trial 20 finished with value: 792.3958044348468 and parameters: {'n_estimators': 517, 'max_depth': 27, 'min_samples_split': 32, 'min_samples_leaf': 32}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:58:56,157] Trial 9 finished with value: 793.2226456998849 and parameters: {'n_estimators': 752, 'max_depth': 207, 'min_samples_split': 33, 'min_samples_leaf': 39}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:00,105] Trial 32 finished with value: 793.4111325607212 and parameters: {'n_estimators': 10, 'max_depth': 374, 'min_samples_split': 26, 'min_samples_leaf': 2}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:01,284] Trial 33 finished with value: 799.8518356775163 and parameters: {'n_estimators': 18, 'max_depth': 371, 'min_samples_split': 27, 'min_samples_leaf': 6}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:06,057] Trial 15 finished with value: 793.2206179330835 and parameters: {'n_estimators': 819, 'max_depth': 259, 'min_samples_split': 36, 'min_samples_leaf': 40}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:10,362] Trial 7 finished with value: 793.1521886726202 and parameters: {'n_estimators': 850, 'max_depth': 372, 'min_samples_split': 32, 'min_samples_leaf': 35}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:30,011] Trial 18 finished with value: 792.7242669346136 and parameters: {'n_estimators': 913, 'max_depth': 120, 'min_samples_split': 36, 'min_samples_leaf': 35}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:30,497] Trial 5 finished with value: 791.0878922177429 and parameters: {'n_estimators': 906, 'max_depth': 136, 'min_samples_split': 13, 'min_samples_leaf': 20}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:42,032] Trial 23 finished with value: 790.2446008234114 and parameters: {'n_estimators': 597, 'max_depth': 60, 'min_samples_split': 11, 'min_samples_leaf': 15}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:47,677] Trial 25 finished with value: 792.2640700872497 and parameters: {'n_estimators': 768, 'max_depth': 311, 'min_samples_split': 2, 'min_samples_leaf': 29}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 10:59:54,849] Trial 21 finished with value: 790.3544927498325 and parameters: {'n_estimators': 922, 'max_depth': 259, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:16,447] Trial 26 finished with value: 791.2523232988289 and parameters: {'n_estimators': 695, 'max_depth': 291, 'min_samples_split': 30, 'min_samples_leaf': 4}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:22,311] Trial 27 finished with value: 788.6972448874901 and parameters: {'n_estimators': 681, 'max_depth': 305, 'min_samples_split': 28, 'min_samples_leaf': 2}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:28,211] Trial 37 finished with value: 790.1516135179932 and parameters: {'n_estimators': 572, 'max_depth': 317, 'min_samples_split': 4, 'min_samples_leaf': 13}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:32,277] Trial 22 finished with value: 791.861821364473 and parameters: {'n_estimators': 995, 'max_depth': 17, 'min_samples_split': 35, 'min_samples_leaf': 5}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:35,820] Trial 28 finished with value: 788.393974359676 and parameters: {'n_estimators': 703, 'max_depth': 323, 'min_samples_split': 27, 'min_samples_leaf': 1}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:40,114] Trial 36 finished with value: 789.7673639954792 and parameters: {'n_estimators': 670, 'max_depth': 317, 'min_samples_split': 3, 'min_samples_leaf': 13}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:43,660] Trial 39 finished with value: 790.1930000251634 and parameters: {'n_estimators': 528, 'max_depth': 173, 'min_samples_split': 2, 'min_samples_leaf': 13}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:46,183] Trial 29 finished with value: 788.5166863245795 and parameters: {'n_estimators': 717, 'max_depth': 393, 'min_samples_split': 29, 'min_samples_leaf': 1}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:47,182] Trial 38 finished with value: 790.3136898837814 and parameters: {'n_estimators': 562, 'max_depth': 315, 'min_samples_split': 5, 'min_samples_leaf': 12}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:49,244] Trial 30 finished with value: 788.4158510031698 and parameters: {'n_estimators': 701, 'max_depth': 400, 'min_samples_split': 27, 'min_samples_leaf': 1}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:50,893] Trial 40 finished with value: 792.0271958281518 and parameters: {'n_estimators': 545, 'max_depth': 329, 'min_samples_split': 40, 'min_samples_leaf': 9}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:51,266] Trial 35 finished with value: 789.4798291200385 and parameters: {'n_estimators': 906, 'max_depth': 97, 'min_samples_split': 4, 'min_samples_leaf': 17}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:51,733] Trial 41 finished with value: 789.9350853353083 and parameters: {'n_estimators': 526, 'max_depth': 172, 'min_samples_split': 40, 'min_samples_leaf': 10}. Best is trial 10 with value: 788.1571195956514.
# [I 2025-04-18 11:00:53,359] Trial 49 finished with value: 787.9490627046491 and parameters: {'n_estimators': 110, 'max_depth': 79, 'min_samples_split': 27, 'min_samples_leaf': 9}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:00:54,027] Trial 44 finished with value: 790.6762840300132 and parameters: {'n_estimators': 269, 'max_depth': 79, 'min_samples_split': 25, 'min_samples_leaf': 8}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:00:58,538] Trial 42 finished with value: 793.1026919692099 and parameters: {'n_estimators': 538, 'max_depth': 176, 'min_samples_split': 5, 'min_samples_leaf': 9}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:00:58,685] Trial 31 finished with value: 790.5748144128771 and parameters: {'n_estimators': 882, 'max_depth': 206, 'min_samples_split': 29, 'min_samples_leaf': 3}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:04,180] Trial 43 finished with value: 792.281639250721 and parameters: {'n_estimators': 506, 'max_depth': 96, 'min_samples_split': 5, 'min_samples_leaf': 9}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:11,163] Trial 46 finished with value: 792.1580409211955 and parameters: {'n_estimators': 599, 'max_depth': 176, 'min_samples_split': 25, 'min_samples_leaf': 8}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:15,072] Trial 47 finished with value: 791.1222725285853 and parameters: {'n_estimators': 674, 'max_depth': 95, 'min_samples_split': 27, 'min_samples_leaf': 8}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:21,530] Trial 48 finished with value: 788.4976017046131 and parameters: {'n_estimators': 628, 'max_depth': 80, 'min_samples_split': 26, 'min_samples_leaf': 1}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:23,988] Trial 45 finished with value: 792.4759221534389 and parameters: {'n_estimators': 987, 'max_depth': 85, 'min_samples_split': 25, 'min_samples_leaf': 9}. Best is trial 49 with value: 787.9490627046491.
# [I 2025-04-18 11:01:25,642] Trial 34 finished with value: 794.3120544818712 and parameters: {'n_estimators': 979, 'max_depth': 98, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 49 with value: 787.9490627046491.
# Best trial:
#   Value (val_mse): 787.9490627046491
#   Params:
#     n_estimators: 110
#     max_depth: 79
#     min_samples_split: 27
#     min_samples_leaf: 9

# %%
best_model = create_pipeline(study.best_trial.params)
train_features, train_target = get_features_and_target(train_df)
best_model.fit(train_features, train_target)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('scaler', StandardScaler(),
#                                                   ['SMOKING_PACK_YEARS',
#                                                    'CNA_CHD5', 'CNA_PTCHD2',
#                                                    'CNA_VPS13D', 'CNA_UBR4',
#                                                    'CNA_HSPG2', 'CNA_ARID1A',
#                                                    'CNA_CSMD2', 'CNA_MACF1',
#                                                    'CNA_LRRC7', 'CNA_C1orf173',
#                                                    'CNA_LPHN2', 'CNA_COL24A1',
#                                                    'CNA_LPPR4', 'CNA_COL11A1',
#                                                    'CNA_S...
#                                                    'CNA_FLG', 'CNA_FLG2',
#                                                    'CNA_FCRL5', 'CNA_SPTA1',
#                                                    'CNA_DUSP27', 'CNA_F5',
#                                                    'CNA_TNN', 'CNA_TNR',
#                                                    'CNA_PAPPA2', 'CNA_ASTN1',
#                                                    'CNA_CACNA1E', ...])])),
#                 ('regressor',
#                  TransformedTargetRegressor(regressor=RandomForestRegressor(max_depth=79,
#                                                                             min_samples_leaf=9,
#                                                                             min_samples_split=27,
#                                                                             n_estimators=110),
#                                             transformer=FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                             inverse_func=<ufunc 'expm1'>)))])

# %%
plot_regression_results_sklearn(best_model, train_df)
